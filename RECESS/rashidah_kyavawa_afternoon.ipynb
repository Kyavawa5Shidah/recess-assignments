# %% [markdown]
# EXERCISE (SET 2)
# DATA ANALYSIS WITH PANDAS
# SERIES

# %% [markdown]
# 1. Write a Pandas program to compare the elements of two Pandas series.
# Sample series[4,65,436,3,9], [7,0,3,897,9]

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Define the two series
series1 = pd.Series([4, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

# Compare the elements of the two series
comparison_result = series1 == series2

# Print the result
print(comparison_result)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# 2.Write a Pandas program to add,subtract, multiply and divide two Pandas series.
# Sample series:[2,4,6,8,14], [1,3,5,7,9]

# %%
# Define the two series
series1 = pd.Series([2, 4, 6, 8, 14])
series2 = pd.Series([1, 3, 5, 7, 9])

# Addition
addition_result = series1 + series2
print("Addition:")
print(addition_result)

# Subtraction
subtraction_result = series1 - series2
print("\nSubtraction:")
print(subtraction_result)

# Multiplication
multiplication_result = series1 * series2
print("\nMultiplication:")
print(multiplication_result)

# Division
division_result = series1 / series2
print("\nDivision:")
print(division_result)
# Out:
# Addition:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
#
# Subtraction:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
#
# Multiplication:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
#
# Division:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %% [markdown]
# 3.Write a Pandas program to convert a dictionary to a Pandas series
# Sample dictionary:dictionary1 = {'Josh':24, 'Sam':36, 'Peace':19, 'Charles':65, 'Tom':44}

# %%
# Define the dictionary
dictionary1 = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}

# Convert dictionary to series
series1 = pd.Series(dictionary1)

# Print the series
print(series1)
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %% [markdown]
# 4.Write a Pandas program to convert a given series to an array.
# Sample series:['Love',800,'Joy',789.9,'Peace',True]

# %%
# Define the series
series1 = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])

# Convert series to array
array1 = np.array(series1)

# Print the array
print(array1)
# Out:
# ['Love' 800 'Joy' 789.9 'Peace' True]

# %% [markdown]
# 5.Write a Pandas program to display the most frequent value in the given series and replace everything else as 'Other' in the series. (Use the 'HomeTeamGoals' column in the dataset provided)

# %%
# reading of the dataset
df = pd.read_csv('AfricaCupofNationsMatches.csv')

# Find the most frequent value
most_frequent_value = df['HomeTeamGoals'].value_counts().idxmax()

# Replace everything else as 'Other'
df.loc[df['HomeTeamGoals'] != most_frequent_value, 'HomeTeamGoals'] = 'Other'

# Display the DataFrame
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#     HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# DATAFRAMES
# (For this section, you will use the 'AfricaCupOfNations' dataset provided to you)

# %% [markdown]
# 1. Write a Pandas program to read the given csv file

# %%
df = pd.read_csv('AfricaCupofNationsMatches.csv')

# Display the DataFrame
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# 2.Write a Pandas program to get the first 7 rows of your data frame

# %%
# Get the first 7 rows of the DataFrame
first_7_rows = df.head(7)

# Display the first 7 rows
print(first_7_rows)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %% [markdown]
# 3.Write a Pandas program to select the 'HomeTeam', 'AwayTeam', 'HomeTeamGoals' and 'AwayTeamGoals' columns from your data frame.

# %%
# Select specific columns
column1 = df['HomeTeam']
column2 = df['AwayTeam']
column3 = df['HomeTeamGoals']
column4 = df['AwayTeamGoals']

# Print the selected columns
print(column1)
print(column2)
print(column3)
print(column4)
# Out:
# 0           Sudan
# 1        Ethiopia
# 2           Egypt
# 3            Egypt
# 4           Sudan
#           ...
# 617    Madagascar
# 618       Senegal
# 619       Algeria
# 620       Tunisia
# 621       Senegal
# Name: HomeTeam, Length: 622, dtype: object
# 0              Egypt
# 1       South Africa
# 2           Ethiopia
# 3           Ethiopia
# 4           Ethiopia
#            ...
# 617          Tunisia
# 618          Tunisia
# 619          Nigeria
# 620          Nigeria
# 621          Algeria
# Name: AwayTeam, Length: 622, dtype: object
# 0      1.0
# 1      NaN
# 2      4.0
# 3      4.0
# 4      1.0
#       ...
# 617    0.0
# 618    1.0
# 619    2.0
# 620    0.0
# 621    0.0
# Name: HomeTeamGoals, Length: 622, dtype: float64
# 0      2.0
# 1      NaN
# 2      0.0
# 3      0.0
# 4      0.0
#       ...
# 617    3.0
# 618    0.0
# 619    1.0
# 620    1.0
# 621    1.0
# Name: AwayTeamGoals, Length: 622, dtype: float64

# %% [markdown]
# 4.Write a Pandas program to select the rows where Egypt appears

# %%
# search for Egypt
country = 'Egypt'

# Select rows where the name appears
selected_rows1 = df[df['HomeTeam'] == country]
selected_rows2 = df[df['AwayTeam'] == country]

# Print the selected rows
print(selected_rows1)
print(selected_rows2)
# Out:
#     Year      Date  Time  HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN    Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN    Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN    Egypt     Uganda            2.0            1.0
# 13  1963  24-Nov-63   NaN    Egypt    Nigeria            6.0            3.0
# 14  1963  26-Nov-63   NaN    Egypt      Sudan            2.0            2.0
# 16  1963  30-Nov-63   NaN    Egypt   Ethiopia            3.0            0.0
#
#                 Stage SpecialWinConditions                 Stadium  \
# 3    Final Tournament                  NaN   Prince Farouk Stadium
# 5    Final Tournament                  NaN   Prince Farouk Stadium
# 7          Semifinals                  NaN  Hailé Sélassié Stadium
# 13            Group B                  NaN   Kumasi Sports Stadium
# 14            Group B                  NaN   Kumasi Sports Stadium
# ...

# %% [markdown]
# 5.Write a Pandas program to count the number of rows and columns of your data frame

# %%
# Count the number of rows and columns
num_rows = df.shape[0]
num_columns = df.shape[1]

# Print the number of rows and columns
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 622
# Number of columns: 12

# %% [markdown]
# 6.Write a Pandas program to select the rows where the 'Attendance' is missing

# %%
# Attendance with missing values
column_name = 'Attendance'

# Select rows with missing values in Attendance
missing_value_rows = df[df[column_name].isnull()]

# Print the selected rows
print(missing_value_rows)
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %% [markdown]
# 7.Write a Pandas program to select rows where the 'HomeTeamGoals' are between 3 and 6 inclusive.

# %%
# HomeTeamGoals to be checked
column_name = 'HomeTeamGoals'

# Select rows where HomeTeamGoals are between 3 and 6 (inclusive)
selected_rows = df[(df[column_name] >= 3) & (df[column_name] <= 6)]

# Print the selected rows
print(selected_rows)
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# ...

# %% [markdown]
# 8.Write a Pandas program to change the 'AwayTeamGoals' in the 3rd row to 10

# %%
# Specify the column and row index you want to change
column_name = 'AwayTeamGoals'
row_index = 2

# Update the value in the specified column and row
df.loc[row_index, column_name] = 10

# Print the updated DataFrame
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# 9.Write a Pandas program to sort the DataFrame first by 'HomeTeam' in ascending order, then by 'HomeTeamScores' in descending order.

# %%
# Sort the DataFrame by the first column in ascending order, then by the second column in descending order
sorted_df = df.sort_values(by=['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])

# Print the sorted DataFrame
print(sorted_df)
# Out:
#      Year                         Date           Time    HomeTeam  \
# 205  1990                      2-Mar-90            NaN   Algeria
# 29   1968                     14-Jan-68            NaN   Algeria
# 135  1980                     16-Mar-80            NaN   Algeria
# 164  1984                      5-Mar-84            NaN   Algeria
# 171  1984                     17-Mar-84            NaN   Algeria
# ..    ...                           ...            ...        ...
# 521  2012                     12-Feb-12  20:30[note 1]    Zambia
# 549  2017  23 January 2017 (2017-01-23)          20:00  Zimbabwe
# 398  2004                     25-Jan-04          16:30  Zimbabwe
# 437  2006                     23-Jan-06          20:00  Zimbabwe
# 575  2019     30 June 2019 (2019-06-30)          21:00  Zimbabwe
#
#          AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 205       Nigeria            5.0            1.0            Group A
# ...

# %% [markdown]
# 10.Write a Pandas program to get list from DataFrame column headers.

# %%
# Get the list of column headers
column_headers = df.columns.tolist()

# Print the list of column headers
print(column_headers)
# Out:
# ['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City', 'Attendance']

# %% [markdown]
# 11.Write a Pandas program to append a column of your choice to your DataFrame.

# %%
# Define the column name you want to append
new_column_name = 'Referee of the match'

# Print the updated DataFrame
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# 12.Write a Pandas program to add 2 rows to your DataFrame

# %%
new_row1 = {'Year': 1957 }
new_row2 = {'Year': 1962 }

# Append the new rows to the DataFrame
df = df.append(new_row1, ignore_index=True)
df = df.append(new_row2, ignore_index=True)

# Print the updated DataFrame
print(df)
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 619  2019  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  1957                        NaN    NaN        NaN            NaN
# 623  1962                        NaN    NaN        NaN            NaN
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# ...

# %% [markdown]
# 13.Write a Pandas program to change the country ' Uganda' to 'China' in the 'Away Team' column of the DataFrame

# %%
# Specify the column and condition to update
column_name = 'AwayTeam'
condition = df[column_name] == 'Uganda'

# Update the value in the specified column based on the condition
df.loc[condition, column_name] = 'China'

# Print the updated DataFrame
print(df)
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 619  2019  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  1957                        NaN    NaN        NaN            NaN
# 623  1962                        NaN    NaN        NaN            NaN
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# ...

# %% [markdown]
# 14.Write a Pandas program to reset index in your DataFrame

# %%
# Reset the index of the DataFrame
df.reset_index(drop=True, inplace=True)

# Print the DataFrame with the reset index
print(df)
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 619  2019  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  1957                        NaN    NaN        NaN            NaN
# 623  1962                        NaN    NaN        NaN            NaN
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# ...

# %% [markdown]
# 15.Write a Pandas program to check whether the 'Stadium' column is present in your DataFrame or not.

# %%
# Check if 'Stadium' column is present
if 'Stadium' in df.columns:
    print("'Stadium' column is present in the DataFrame.")
else:
    print("'Stadium' column is not present in the DataFrame.")
# Out:
# 'Stadium' column is present in the DataFrame.

# %% [markdown]
# 16.Write a Pandas program to convert the datatype of the 'AwayTeamGoals'.(int to float)

# %%
# Convert the data type of 'AwayTeamGoals' column from int to float
df['AwayTeamGoals'] = df['AwayTeamGoals'].astype(float)

# Print the updated DataFrame
print(df)
# Out:
#      Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959                  25-May-59    NaN     Sudan        Ethiopia
# ..    ...                        ...    ...        ...            ...
# 619  2019  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622  1957                        NaN    NaN        NaN            NaN
# 623  1962                        NaN    NaN        NaN            NaN
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# ...

# %% [markdown]
# 17.Write a Pandas program to remove the last 10 rows from your DataFrame

# %%
# Remove the last 10 rows from the DataFrame
df = df.iloc[:-10]

# Print the updated DataFrame
print(df)
# Out:
#      Year                     Date   Time      HomeTeam       AwayTeam  \
# 0    1957                 10-Feb-57    NaN       Sudan           Egypt
# 1    1957                 10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                 16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                 22-May-59    NaN        Egypt       Ethiopia
# 4    1959                 25-May-59    NaN       Sudan        Ethiopia
# ..    ...                       ...    ...          ...            ...
# 609  2019  6 July 2019 (2019-07-06)  21:00       Egypt    South Africa
# 610  2019  7 July 2019 (2019-07-07)  18:00  Madagascar        DR Congo
# 611  2019  7 July 2019 (2019-07-07)  21:00     Algeria          Guinea
# 612  2019  8 July 2019 (2019-07-08)  18:00        Mali     Ivory Coast
# 613  2019  8 July 2019 (2019-07-08)  21:00       Ghana         Tunisia
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# ...

# %% [markdown]
# 18.Write a Pandas program to iterate over rows in your DataFrame.

# %%
#Removing white spaces
df.columns = df.columns.to_series().apply(lambda x :x.strip())
df.columns
# Out:
# Index(['Year', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
#        'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City',
#        'Attendance'],
#       dtype='object')

# %%
# Iterate over rows in the DataFrame
for index, row in df.iterrows():
    # Access values for 12 columns
    column1_value = row['Year']
    column2_value = row['Date']
    column3_value = row['Time']
    column4_value = row['HomeTeam']
    column5_value = row['AwayTeam']
    column6_value = row['HomeTeamGoals']
    column7_value = row['AwayTeamGoals']
    column8_value = row['Stage']
    column9_value = row['SpecialWinConditions']
    column10_value = row['Stadium']
    column11_value = row['City']
    column12_value = row['Attendance']
    
    # Print the values for the 12 columns
    print(column1_value, column2_value, column3_value, column4_value, column5_value, column6_value, column7_value, column8_value, column9_value, column10_value, column11_value, column12_value)
# Out:
# 1957 10-Feb-57 nan Sudan   Egypt 1.0 2.0 Semifinals nan Municipal Stadium  Khartoum 30000.0
# 1957 10-Feb-57 nan Ethiopia   South Africa nan nan Semifinals Ethiopia  wins due to disqualification of other team nan nan nan
# 1957 16-Feb-57 nan Egypt   Ethiopia 4.0 10.0 Final nan Municipal Stadium  Khartoum 30000.0
# 1959 22-May-59 nan Egypt  Ethiopia 4.0 0.0 Final Tournament nan Prince Farouk Stadium  Cairo 30000.0
# 1959 25-May-59 nan Sudan   Ethiopia 1.0 0.0 Final Tournament nan Prince Farouk Stadium  Cairo 20000.0
# 1959 29-May-59 nan Egypt  Sudan 2.0 1.0 Final Tournament nan Prince Farouk Stadium  Cairo 30000.0
# 1962 14-Jan-62 nan Ethiopia   Tunisia 4.0 2.0 Semifinals nan Hailé Sélassié Stadium  Addis Ababa 30000.0
# 1962 18-Jan-62 nan Egypt  Uganda 2.0 1.0 Semifinals nan Hailé Sélassié Stadium  Addis Ababa 30000.0
# 1962 20-Jan-62 nan Tunisia   Uganda 3.0 0.0 Third place match nan Hailé Sélassié Stadium  Addis Ababa nan
# ...

# %% [markdown]
# 19.Write a Pandas program to change the order of your DataFrame columns

# %%
# Define the desired order of column name
new_column_order =['Attendance', 'City', 'Stadium', 'SpecialWinConditions', 'Stage', 'AwayTeamGoals', 'HomeTeamGoals', 'AwayTeam', 'HomeTeam', 'Time', 'Date', 'Year']

# Reorder the columns based on the new order
df = df[new_column_order]

# Print the DataFrame with the new column order
print(df)
# Out:
#      Attendance         City                      Stadium  \
# 0       30000.0     Khartoum            Municipal Stadium
# 1           NaN          NaN                          NaN
# 2       30000.0     Khartoum            Municipal Stadium
# 3       30000.0        Cairo        Prince Farouk Stadium
# 4       20000.0        Cairo        Prince Farouk Stadium
# ..          ...          ...                          ...
# 609     75000.0        Cairo  Cairo International Stadium
# 610      5890.0   Alexandria           Alexandria Stadium
# 611      8205.0        Cairo              30 June Stadium
# 612      7672.0         Suez                 Suez Stadium
# 613      8890.0     Ismailia             Ismailia Stadium
#
#                                   SpecialWinConditions             Stage  \
# 0                                                  NaN        Semifinals
# 1    Ethiopia  wins due to disqualification of othe...        Semifinals
# ...

# %% [markdown]
# 20.Write a Pandas program to delete DataFrame row(s) whose values is 0 in the 'HomeTeamGoals' columns.

# %%
# Filter rows where 'HomeTeamGoals' is not equal to 0
df = df[df['HomeTeamGoals'] != 0]

# Print the updated DataFrame
print(df)
# Out:
#      Attendance         City                Stadium  \
# 0       30000.0     Khartoum      Municipal Stadium
# 1           NaN          NaN                    NaN
# 2       30000.0     Khartoum      Municipal Stadium
# 3       30000.0        Cairo  Prince Farouk Stadium
# 4       20000.0        Cairo  Prince Farouk Stadium
# ..          ...          ...                    ...
# 606      7500.0        Cairo       Al Salam Stadium
# 608     10000.0   Alexandria     Alexandria Stadium
# 610      5890.0   Alexandria     Alexandria Stadium
# 611      8205.0        Cairo        30 June Stadium
# 613      8890.0     Ismailia       Ismailia Stadium
#
#                                   SpecialWinConditions             Stage  \
# 0                                                  NaN        Semifinals
# 1    Ethiopia  wins due to disqualification of othe...        Semifinals
# 2                                                  NaN             Final
# ...
